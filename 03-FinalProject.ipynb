# %% [markdown]
# # COGS 108 - Secondary Education to College to 2009-2016 Longitudinal Study Data
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [X] YES - make available
# * [  ] NO - keep private
#
# ## Link to video
# https://link.to.your.publicly.viewable.video
#
# ## Abstract
#
# A recent report on remedial math scores from students at UCSD have raised a concern for the discrepancy between a student's expected prepardness for college education and their test scores. The report also noted UCSD's increase admission for underfunded schools. This got us interested if this disparity was due to environmental factors or the student's own academic preparation.
#
# We began by finding a dataset that gave us a large sample size of each student's GPA, AP/IB credit, SAT/ACT scores, and hours of work they did in high school. These are all academic based. For their environmental factors, we pulled out a list of variables related to their school and family background that gave us a better picture of their background. Lastly, we had data of their first year of college GPA, which is the predictor of our project. We selected values that we wanted and created visualizations and models to test our hypothesis.
#
# Our major finding is that high school academic performance, especially cumulative high school GPA, is the strongest predictor of first-year college GPA. AP/IB credit and SES also show meaningful positive associations, while school climate and motivation show weaker but noticeable relationships. By contrast, factors like household size and school mobility show little predictive signal in our sample. Overall, our results suggest that sustained academic preparation is the most consistent indicator of first-year success, while environmental context appears to play a secondary, moderating role.

# %% [markdown]
# # Authors
# This is a modified [CrediT taxonomy of contributions](https://credit.niso.org). For each group member please list how they contributed to this project using these terms:
# > Analysis, Background research, Conceptualization, Data curation, Experimental investigation, Methodology, Project administration, Software, Visualization, Writing – original draft, Writing – review & editing
#
# Example team list and credits:
# - Jaden Wu: Conceptualization, data wrangling, modeling
# - Trenton Pham: Database, Data visualization, documentation
# - Juhoan Cha: documentation, data visualiation
# - Minh Tue Nguyen: Data Visualization, background research, writing - Original draft & review
# - Shawn Le:Data Visualization, writing - original draft & review

# %% [markdown]
# ## Research Question

# %% [markdown]
# To what extent do pre-college academic indicators predict first-year college academic performance? Using a dataset containing high school GPA, standardized test scores (SAT math and verbal), coursework rigor (e.g., number of AP/IB courses), and high school context (e.g., school competitiveness), we model students’ first-year college performance. This project evaluates the relative and combined predictive power of these variables using regression and classification approaches. We further analyze whether certain preparation profiles systematically overperform or underperform relative to model expectations. This predictive modeling task aims to identify which aspects of high school success transfer most effectively to early college performance.

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Recent national discussions around college readiness have been brought into sharp focus at UC San Diego, where reports of a growing remedial math placement rate among incoming students have gained mainstream attention. As UCSD students, we were motivated by this issue after the Academic Senate released a Senate–Administration Working Group (SAWG) report analyzing admissions practices and student academic preparedness. The report highlights a notable increase in the number of incoming students requiring remedial-level math instruction, raising concerns about the alignment between pre-college preparation and college-level expectations.<a name="cite_ref-1"></a><sup>1</sup>
#  This development has prompted broader questions about how well traditional indicators of academic readiness translate into early college success.
#
# The SAWG report attributes part of this trend to changes in UCSD’s admissions landscape, including increased enrollment of students from under-resourced and lower-funded high schools.<a name="cite_ref-1"></a><sup>1</sup>
#  While the report does not claim that students from these schools are incapable of succeeding, it emphasizes that disparities in access to advanced coursework and academic resources may affect readiness for college-level mathematics. Importantly, the report suggests that commonly used admissions metrics may not fully capture differences in academic preparation, motivating further investigation into which pre-college factors meaningfully predict early college performance.
#
# Prior research and exploratory projects have examined similar questions using simplified academic datasets. One such example is a publicly documented Kaggle project that analyzed the relationship between high school GPA, SAT scores, and first-year college GPA using linear regression.<a name="cite_ref-2"></a><sup>2</sup>
#  That project found that high school GPA exhibited a slightly stronger correlation with first-year college GPA than SAT scores, suggesting that sustained academic performance may be a better indicator of early college success than standardized testing alone. The analysis also explored gender differences, observing small performance disparities despite similar SAT and high school GPA distributions.
#
# These findings align with broader education research suggesting that no single pre-college metric fully explains college outcomes. Geiser and Santelices (2007), using University of California admissions and outcomes data, report that high school GPA is a stronger and more consistent predictor of college success than standardized test scores across multiple outcomes.<a name="cite_ref-3"></a><sup>3</sup>
#  In a community college placement context, Belfield and Crosta (2012) compared placement-test-only approaches with transcript-based predictors and found that using high school performance indicators can improve placement decisions and reduce misclassification.<a name="cite_ref-4"></a><sup>4</sup>
#  More recent work by Allensworth and Clark (2020), which uses hierarchical modeling across high schools, shows that GPA remains a relatively stable predictor while test-score predictive power varies more across school contexts.<a name="cite_ref-5"></a><sup>5</sup>
#  Together, these methods-based findings suggest that model performance depends on both variable choice and institutional context, not just the algorithm itself.
#
# Building on both institutional reporting and prior data-driven projects, our work seeks to extend this line of inquiry by examining a broader set of pre-college academic indicators and their relationship to early college performance. In addition to SAT and high school GPA, prior studies motivate including variables tied to coursework rigor and educational context (for example, AP/IB exposure, first-generation status, and school-resource context) because these factors may mediate how test scores translate into first-year outcomes.<a name="cite_ref-4"></a><sup>4</sup><a name="cite_ref-5"></a><sup>,5</sup>
#  By situating our analysis within the context of the UCSD remedial math discussion and grounding our variable selection in existing methods-focused literature, this project aims to better understand the practical limits of commonly used readiness metrics and identify which aspects of high school preparation are most strongly associated with first-year college success.
#
# References
#
# <a name="cite_note-1"></a> 1
#  UC San Diego Academic Senate. Report of the Senate–Administration Working Group on Admissions Review. UCSD, 2023. https://senate.ucsd.edu/media/740347/sawg-report-on-admissions-review-docs.pdf
#
# <a name="cite_note-2"></a> 2
#  Kaggle Discussion. Predicting College Success Using SAT and GPA. Kaggle, 2024. https://www.kaggle.com/discussions/getting-started/542760#3036652
#
# <a name="cite_note-3"></a> 3
#  Geiser, S., & Santelices, M. V. (2007). Validity of High-School Grades in Predicting Student Success Beyond the Freshman Year. UC Berkeley Center for Studies in Higher Education. https://cshe.berkeley.edu/publications/validity-high-school-grades-predicting-student-success-beyond-freshman-year-high-school
#
# <a name="cite_note-4"></a> 4
#  Belfield, C. R., & Crosta, P. M. (2012). Predicting Success in College: The Importance of Placement Tests and High School Transcripts. Community College Research Center, Teachers College, Columbia University. https://ccrc.tc.columbia.edu/publications/predicting-success-placement-tests-transcripts.html
#
# <a name="cite_note-5"></a> 5
#  Allensworth, E., & Clark, K. (2020). High school GPAs and ACT scores as predictors of college completion: Examining assumptions about consistency across high schools. Educational Researcher. https://doi.org/10.3102/0013189X20902110

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# Our group hypothesises that while high school GPA and SAT scores are a strong indicator for college success, environmental context factors (e.g., school structure and socioeconomic context) also play a gigantic role beyond academics alone. Students that are set up well in good envionments alongside taking rigorous classes have a much better chance of succeeding within college, whether its having higher first-year GPA, more credits earned, or a lower remedial-course rates.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# 1) Ideal dataset
# - The ideal dataset for this project would include a range of academic and demographic variables carefully selected based on their established relationship with first-year college GPA in existing academic literature. The primary predictor variables would include SAT Score (Math and Verbal), High School GPA, number of AP/IB courses completed, demographic background, gender, and first-generation college student status; commonly cited factors towards college performance. A sample size of at least 5,000 entries is targeted to ensure the model has enough data to identify meaningful patterns, reduce variance in predictions, and produce results that generalize well beyond the training set. A smaller sample risks producing an underfitted or unreliable model, particularly when accounting for the diversity of demographic subgroups within the data.
#
# 2) Current dataset
# - Our dataset have currently been identified on https://nces.ed.gov/surveys/hsls09/hsls09_data.asp, a platform that provides freely accessible statistical datasets from a high school to college/post-secondary education longtitudinal study. The data was collected from 2009-2016 that tracks students from secondary education to college, and each contains variables relevant to this project including first-year college GPA, cumulative high school GPA, SAT Math and SAT Verbal scores, first-generation status, demographic background, and gender. This dataset contains over 23,000 entries, way beyond our ideal sample size.
#
# - A key consideration going forward is how the dataset will be used in the modeling process. We are currently extracting features to be used for the modeling process and an outcome variable. A final decision will be made after a thorough review of each dataset's structure, variable definitions, and any accompanying documentation.

# %% [markdown]
# ### Secondary Education to College to 2009-2016 Longitudinal Study Data
#
# **NOTE** To see how we narrowed down from 9000 variables to 25, checkout `02-EDACheckpoint.ipynb`, where we showcased our initially draft of variables that correlated with academics. To see how we choose our enviornmental context(school, family situation, etc) checkout `variable_selection.ipynb`, where we analyzed and added new target variables, and also readjusted our current variables.
#
# We will now just be using the processed version of the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
comb_df = pd.read_csv('data/02-processed/hsls_24_final_vars.csv').dropna()
comb_df = comb_df[(comb_df > -6).all(axis=1)] # removes all variables greater than -7
comb_df = comb_df.drop(columns=['Unnamed: 0', 'REMEDIAL_COURSE_RATIO', ])
df_hs_cum = comb_df[['HS_GPA_9TH', 'HS_GPA_10TH', 'HS_GPA_11TH', 'HS_GPA_12TH']]
comb_df['HS_GPA_CUM'] = df_hs_cum.mean(axis=1)
print(comb_df.columns)
# Out:
# Index(['FAMILY_INCOME_BRACKET', 'HOUSEHOLD_SIZE',
#        'SES_COMPOSITE_URBANICITY_ADJ', 'NUM_HS_ATTENDED',
#        'SCHOOL_PROBLEM_SCALE', 'SCHOOL_CLIMATE_SCALE',
#        'STUDENT_SCHOOL_MOTIVATION', 'TOTAL_AP_CREDITS', 'RIGOR', 'HS_GPA_12TH',
#        'HS_GPA_11TH', 'HS_GPA_10TH', 'HS_GPA_9TH', 'HS_GPA_ACAD', 'HS_GPA_WGT',
#        'SAT_WRIT_AVG', 'ACT_SCHOOL_AVG', 'FRESHMAN_GPA',
#        'FRESHMAN_CREDITS_ATTEMPTED', 'FRESHMAN_CREDITS_EARNED',
#        'ENROLLMENT_ATTAINMENT_STATUS', 'SAT_SCHOOL_AVG', 'HOURS_HOMEWORK',
#        'HS_GPA_CUM'],
#       dtype='object')

# %% [markdown]
# #### Column Information (Curriculum - 'X3TNEWBASIC')
# - 1	College-bound core curriculum
# - 2	Core curriculum
# - 3	College-bound core without computer sciences
# - 4	Core without computer sciences
# - 5	Minimal core curriculum
# - 6	All other patterns
# - -8	Unit non-response
# - TOTAL		23,503	99.99
# - 1 UnW = Unweighted

# %% [markdown]
# # Potential Predictor Columns
# ### Student Context
# - Curriculum: 'RIGOR',
#
# > Curriculum pertains to the intensity and composition of their coursework. Values indicate whether students completed a college-bound core curriculum, a college-bound core curriculum without computer science, a standard core curriculum without computer science, a minimal core curriculum, or other curricular patterns. This variable is indicative of coursework rigor and academic preparation prior to college.
#
# - Grades (9-12, Academic Track, and Weighted): 'HS_GPA_9TH', 'HS_GPA_10TH', 'HS_GPA_11TH', 'HS_GPA_12TH', 'HS_GPA_ACAD','HS_GPA_WGT',
#
# > Grades (gpa) pertains to the level of success a student was able to achieve throughout their high school career. Grade specific gpas represent annual academic performance on a standard gpa scale, allowing analysis of trends over time. The academic-track gpa (X3TGPAACAD) reflects performance specifically in college-preparatory courses, while the weighted GPA (X3TGPAWGT) adjusts for course difficulty by giving additional weight to honors, AP, or IB classes. Together, these GPA metrics provide a comprehensive measure of sustained academic performance and/or academic growth through high school.
#
# - Time Spent Studying: 'HOURS_HOMEWORK'
#
# > These columns give the average time each student spent studying for math, science, and other homework in total for each school day in high school. This can reveal how much time a student committed to working in school, which can reflect on their grades. A student who has dedicated more time into school is expected to be more prepared for higher education than students do not. This column is feature engineered through combining the specific study times for math, science, and other, where the original columns were dropped in favor of total study time.
#
# - AP/IB Credit: 'TOTAL_AP_CREDITS'
# > Since AP/IB credit is meant to be college level courses in high school that allows the student to get college credit if they do well enough on an objective exam that is given at the end of the course content. If they do get college credit, this can mean that they are more prepared for college-level course work than others who have not.
#
# ### School Context
# - School Avg SAT Per School: 'SAT_SCHOOL_AVG'
#
# > These include the average SAT Math and Reading scores for each student’s high school. These can be indicative of school competitiveness and peer academic ability. Higher average scores could suggest a more academically selective or high-performing school environment, which may influence students' college readiness through peer effects and instructional quality.
#
# - School Avg ACT Per School: 'ACT_SCHOOL_AVG'
#
# > The dataset also includes school average ACT performance. Similar to the school average SAT variables, these metrics capture the academic environment and competitiveness of each student's high school. Schools with higher average ACT scores might provide stronger academic preparation and academically engaged peer groups, which may indirectly affect students’ readiness for college coursework.
#
# - Standardized School Score (by Administrators): 'SCHOOL_PROBLEM_SCALE', 'SCHOOL_CLIMATE_SCALE'
#
# > The dataset includes a standardized school score reported by administrators. This measure the school academic and social environment which may play a factor into student's academic performance. These social factors may impact student performance and their post-secondary studies through influence and traits taken by other students or social contexts. However, since the score is reported by school administrators, there are potential concerns regarding false-reported scores, which indicate bias in favor of the school.
#
# - Standardized School Score (by students): 'STUDENT_SCHOOL_MOTIVATION'
#
# > The dataset also includes a standardized school score reported by the students themselves. This indicates the student's own perspectives on the school environment rather than the eyes of the school administrators.
#
# ### Family Context
# - Family Income Bracket & Socioeconomic Status: 'FAMILY_INCOME_BRACKET', 'SES_COMPOSITE_URBANICITY_ADJ'
#
# > The dataset includes family income bracket and socioeconomic status relative to the area they live in. The family income bracket gives contexts onto student's backgrounds. Knowing information such as family income assists in understanding the context behind academic performance, in which students in much lower income brackets tend to struggle more in academics due to mental, physical, and social caveats.
#
# - Number of Family Members: 'HOUSEHOLD_SIZE'
#
# > This dataset contains the number of family members per household. Household size can play a factor in academic performance, specifically with much larger household sizes due to the dilution of resources such as time, money, and attention. As the household size increases, it leads to less individualized attention for each kids.
#
# - Number of High Schools Attended: 'NUM_HS_ATTENDED'
#
# > The dataset includes the number of high schools attended. The number of high schools attended can often affect student performance due to disrupting the student socially. In addition, curriculums vary from school to school, in which gaps of knowledge are often created due to a changed pace, causing students to often repeat material.
#
# #### Column Information (Curriculum - 'RIGOR')
# - 1	College-bound core curriculum
# - 2	Core curriculum
# - 3	College-bound core without computer sciences
# - 4	Core without computer sciences
# - 5	Minimal core curriculum
# - 6	All other patterns
# - -8	Unit non-response
# - TOTAL		23,503	99.99
# - 1 UnW = Unweighted
#
# ### Potential Outcomes
# - College GPA: "FRESHMAN_GPA", "FRESHMAN_CREDITS_ATTEMPTED", 'FRESHMAN_CREDITS_EARNED', "ENROLLMENT_ATTAINMENT_STATUS"

# %% [markdown]
# #### College Freshman GPA Distribution
# This histogram shows the GPA distribution of college freshmen, showing that the distribution is very right skewed. This means that most people are getting an average grade of A's and B's in their classes. The density plot is graphed on top of this to show a distribution that is easier to interpret with a continuous line rather than the ridged histogram. Note that there seems to be a spike in people receiving a GPA close to 0. This is not clarified in the dataset, so we have decided to not remove it for this project. However, we have hypothesized that it is people who have dropped out and have no record of a GPA or people who have failed all their classes. Also note that we have removed any N/A's values and negative values (values that are not recorded).

# %%
plt.figure(figsize=(6, 4))
sns.histplot(comb_df['FRESHMAN_GPA'], bins=30, kde=True, binwidth=0.2)
plt.axvline(comb_df['FRESHMAN_GPA'].mean(), color='red', linestyle='--', label='Mean GPA')
plt.title('Distribution of Freshman GPA')
plt.xlabel('Freshman GPA')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Cumulative High School GPA Distribution
# This histogram and density plot is similar to the one above, showing how right skewed the data is. However, this data does not have a spike in zeros like the previous graph. This goes well with our hypothesis that the zeroes can represent people dropping out. This was made to compare the distribution of the two variables. Evidently, they look quite similar in the density plot, but the real values differ slightly. For high school GPA, there was a large number of students receiving 4.0's, but this has drastically decreased when we look at the density axis. The proportion in which students were getting high school GPA's are significantly higher than college GPA's. However, this is a generalization, not a representation of each student.

# %%
df_hs_cum = comb_df[['HS_GPA_9TH', 'HS_GPA_10TH', 'HS_GPA_11TH', 'HS_GPA_12TH']]
df_hs_cum['HS_GPA_CUM'] = df_hs_cum.mean(axis=1)
plt.figure(figsize=(6, 4))
sns.histplot(df_hs_cum['HS_GPA_CUM'], bins=30, kde=True, binwidth=0.2)
plt.axvline(df_hs_cum['HS_GPA_CUM'].mean(), color='red', linestyle='--', label='Mean GPA')
plt.title('Distribution of Cumulative High School GPA')
plt.xlabel('Cumulative High School GPA')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/xg/pjqjkzbx1lz9fgmz_njxvl6w0000gn/T/ipykernel_55697/3060891368.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hs_cum['HS_GPA_CUM'] = df_hs_cum.mean(axis=1)

# %% [markdown]
# ### HS GPA (9-12) vs Cumulative HS GPA vs Freshman GPA
# This boxplot displays the distribution of all high school GPAs per grade, cumulative, and college freshman GPAs. This was made to show the comparison between high school and college GPAs in a clearer manner and to support the two
# distribution histograms above.
#
# - Some notes that we had was how the HS 10th grade gpa was slightly wider compared to the rest of the other class levels. We hypothesize how 10th grade is a bigger jump in difficulty compared to freshmen year, therefore students are less prepared for it.

# %%
df_gpas = df_hs_cum[['HS_GPA_9TH', 'HS_GPA_10TH', 'HS_GPA_11TH', 'HS_GPA_12TH','HS_GPA_CUM']]
df_gpas['FRESHMAN_GPA'] = comb_df['FRESHMAN_GPA']

plt.figure(figsize=(8,4))
sns.boxplot(
    data=df_gpas
)
plt.title('HS GPA (9-12) vs Cumulative HS GPA vs Freshman GPA')
plt.ylabel('GPA')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Pairplot for Freshman and High School GPA and ACT Composite Score
# This pairplot is an overview on each variable given above. One of our predictors to determine college preparedness is ACT Composite Score, so we want to see if it has any correlation with both college freshman GPA and high school GPA. This also shows the correlation between college and high school GPA, which is more difficult to read, so there is a more comprehensive graph and explanation below. Comparing these variable side to side makes it easier to analyze. Notice that ACT may not be the best predictor for readiness as there is not really a trend for either graphs.

# %%
comb_df['HS_GPA_CUM'] = df_hs_cum['HS_GPA_CUM']
sns.pairplot(comb_df, vars=['HS_GPA_CUM', 'ACT_SCHOOL_AVG','FRESHMAN_GPA'])

# %% [markdown]
# #### Freshman GPA vs High School GPA
# This LM plot is used to show whether or not there is some correlation in high school GPA and college freshman GPA for each student. The plot illustrates a general upward slope that suggests there is some correlation, but the points are very spread out, so the correlation is low. There are instances of some students received a high school GPA, but their freshman GPA shows close to a 0, which indicates some external circumstances such as dropping out. Knowing that there are external factors contributing to the drastic GPA change between high school and college freshman years, we will be analyzing outside factors next.

# %%
df_gpas = comb_df[['HS_GPA_9TH', 'HS_GPA_10TH', 'HS_GPA_11TH', 'HS_GPA_12TH']]
df_gpas['HS_GPA_CUM'] = df_gpas.mean(axis=1).dropna()
df_gpas = df_gpas.assign(FRESHMAN_GPA = comb_df['FRESHMAN_GPA'])
df_filtered = df_gpas[
    (df_gpas['HS_GPA_CUM'] >= 0) &
    (df_gpas['FRESHMAN_GPA'] >= 0)]
sns.lmplot(
    data=df_filtered,
    x='HS_GPA_CUM',
    y='FRESHMAN_GPA',
    x_jitter=0.05,
    y_jitter=0.05,
    fit_reg=True,
    scatter_kws={"s": 8},
    line_kws={'color': 'red'}
)
plt.title('Freshman GPA vs High School GPA')
plt.show()

X = sm.add_constant(df_filtered['HS_GPA_CUM'])
y = df_filtered['FRESHMAN_GPA']
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
# /var/folders/xg/pjqjkzbx1lz9fgmz_njxvl6w0000gn/T/ipykernel_55697/1091308654.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gpas['HS_GPA_CUM'] = df_gpas.mean(axis=1).dropna()
#                             OLS Regression Results
# ...
# Dep. Variable:           FRESHMAN_GPA   R-squared:                       0.333
# Model:                            OLS   Adj. R-squared:                  0.333
# Method:                 Least Squares   F-statistic:                     1127.
# Date:                Wed, 18 Mar 2026   Prob (F-statistic):          8.57e-201
# Time:                        20:01:38   Log-Likelihood:                -2539.9
# No. Observations:                2259   AIC:                             5084.
# ...

# %% [markdown]
# #### AP/IB Credit vs. Ratio of Credits Earned
# This scatterplot shows how much AP/IB credit the student earned in high school, which is meant to be a college-level course, versis the ratio of credits earned over credits attempted. This shows the ratio of classes the student passed, similar to how AP/IB credit works. AP/IB credit is earned when a student passes an exam that is cummulative of the contents of the class. Whether or not they receive credit should be similar to whether or not they are going to pass an equivalent class in college. This means that the ratio in which they are earning credit should correlate to how much AP/IB credit they earned. In this case, a ratio of 1 should be the max, however, there seems to be some error where some students are earning twice as much credit as they have attempted. Additionally, it seems that most students did not have AP or IB credit coming into college, so there is not as much data to work off of for this variable.

# %%
credits_df = comb_df[['TOTAL_AP_CREDITS', 'FRESHMAN_GPA']]
credits_df = credits_df.assign(ratio = (comb_df['FRESHMAN_CREDITS_EARNED'] / comb_df['FRESHMAN_CREDITS_ATTEMPTED']))
credits_df = credits_df.dropna()
credits_df = credits_df[(credits_df['ratio'] >= 0) &
                        (credits_df['ratio'] <= 8) &
                        (credits_df['TOTAL_AP_CREDITS'] >= 0)]
sns.scatterplot(data = credits_df, x = 'TOTAL_AP_CREDITS', y = 'ratio')
plt.xlabel('AP and IB Credit')
plt.ylabel('Ratio of Credits Earned Over Credits Attempted')
plt.title('AP/IB Credit VS. Ratio of Credits Earned')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Freshman Credits: Attempted vs Earned
# This scatterplot shows how much credits are earned relative to the amount of credits attempted in their freshman year of college. Similar to the scatterplot above, this shows the difference in classes earned (passed) than the amount of credits attempted (dropped or failed). In this case, a slope 1 should be the max, however, there seems to be some error where some students are earning twice as much credit as they have attempted. Interpreting from this graph, it seems like there is a positive correlation in the amount of credits earned relative to the amount of credits attempted.

# %%
plt.figure(figsize=(6, 4))
sns.scatterplot(
    data=comb_df,
    x='FRESHMAN_CREDITS_ATTEMPTED',
    y='FRESHMAN_CREDITS_EARNED',
    alpha=0.4
)
max_val = max(comb_df['FRESHMAN_CREDITS_ATTEMPTED'].max(),
              comb_df['FRESHMAN_CREDITS_EARNED'].max())
plt.plot([0, max_val], [0, max_val], color='red', linestyle='--', label='Earned = Attempted')
plt.title('Freshman Credits: Attempted vs Earned')
plt.xlabel('Credits Attempted')
plt.ylabel('Credits Earned')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Freshman GPA by High School Coursework Rigor
# This boxplot shows the GPA achieved in student's freshman year of college relative to the coursework they've done in high school. Here is information about what each rigor stands for:
# - 1	College-bound core curriculum
# - 2	Core curriculum
# - 3	College-bound core without computer sciences
# - 4	Core without computer sciences
# - 5	Minimal core curriculum
# - 6	All other patterns
#
# Shown in the boxplots, the mean GPA tends to be higher for students that have taken a college-bound core curriculum in high school.

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(
    data=comb_df,
    x='RIGOR',
    y='FRESHMAN_GPA'
)
plt.title('Freshman GPA by High School Coursework Rigor')
plt.xlabel('Rigor (higher = more rigorous coursework)')
plt.ylabel('Freshman GPA')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Freshman GPA by AP/IB Credit Bin
# This boxplot shows the GPA in freshman year of college relative to the amount of AP/IB credits earned in high school. Since students with more credits had more exposure to college-level coursework in high school, it leads to a positive trend in terms of their GPA in college, shown with the higher means.

# %%
credits_df = comb_df[['TOTAL_AP_CREDITS', 'FRESHMAN_GPA']].copy()
credits_df['ratio'] = comb_df['FRESHMAN_CREDITS_EARNED'] / comb_df['FRESHMAN_CREDITS_ATTEMPTED']
credits_df = credits_df.dropna()
credits_df = credits_df[
    (credits_df['ratio'] >= 0) &
    (credits_df['ratio'] <= 8) &
    (credits_df['TOTAL_AP_CREDITS'] >= 0)
].copy()

credits_df['apib_bin'] = pd.cut(
    credits_df['TOTAL_AP_CREDITS'],
    bins=[-0.1, 0, 3, 6, 999],
    labels=['0 credits', '1–3 credits', '4-6 credits', '7+ credits']
)

plt.figure(figsize=(8, 4))
sns.boxplot(
    data=credits_df,
    x='apib_bin',
    y='FRESHMAN_GPA'
)
plt.title('Freshman GPA by AP/IB Credit Bin')
plt.xlabel('AP/IB Credits')
plt.ylabel('Freshman GPA')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Distribution of Daily Homework Hours
#
# This histogram shows the distribution of daily homework hours among students. Most students spend around 3 to 6 hours on homework, with the highest frequency centered near this range. The distribution is slightly right-skewed, indicating that while most students spend a moderate amount of time, a smaller number of students spend significantly more hours on homework.

# %%
comb_df = comb_df[comb_df['HOURS_HOMEWORK'] >= 0]

plt.figure(figsize=(6, 4))
sns.histplot(
    comb_df['HOURS_HOMEWORK'],
    binwidth=1,
    kde=True
)
plt.title('Distribution of Daily Homework Hours')
plt.xlabel('Hours of Homework per School Day')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Distribution of High School Average SAT
# This histogram shows the distribution of average SAT scores across high schools. Most values are concentrated around the middle range (approximately 1000 to 1150), indicating that many schools have similar average performance. The distribution is roughly bell-shaped, with fewer schools at the very low and very high ends of the SAT range.

# %%
plt.figure(figsize=(6, 4))
sns.regplot(
    data=comb_df,
    x='HOURS_HOMEWORK',
    y='FRESHMAN_GPA',
    lowess=True,
    scatter_kws={'alpha': 0.2}
)
plt.title('Freshman GPA vs. Daily Homework Hours')
plt.xlabel('Hours of Homework per School Day')
plt.ylabel('Freshman GPA')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Distribution of High School Average SAT
# This histogram shows the distribution of average SAT scores across high schools. Most values are concentrated around the middle range (approximately 1000 to 1150), indicating that many schools have similar average performance. The distribution is roughly bell-shaped, with fewer schools at the very low and very high ends of the SAT range.

# %%
plt.figure(figsize=(6, 4))
sns.histplot(
    comb_df['SAT_SCHOOL_AVG'],
    binwidth=50,
    kde=True
)
plt.title('Distribution of High School Average SAT')
plt.xlabel('School Average SAT')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Freshman GPA by High School SAT Quartile
# This boxplot shows the distribution of freshman GPA across different quartiles of high school average SAT scores. Students from higher SAT quartiles tend to have slightly higher median GPAs, suggesting a positive relationship between school SAT performance and college GPA. However, there is still noticeable variation within each group.

# %%
sat = comb_df[['SAT_SCHOOL_AVG', 'FRESHMAN_GPA']].dropna().copy()
sat['SAT_QUARTILE'] = pd.qcut(sat['SAT_SCHOOL_AVG'], 4, labels=['Q1', 'Q2', 'Q3', 'Q4'])

plt.figure(figsize=(6, 4))
sns.boxplot(
    data=sat,
    x='SAT_QUARTILE',
    y='FRESHMAN_GPA'
)
plt.title('Freshman GPA by High School SAT Quartile')
plt.xlabel('School Average SAT Quartile (Q1 = lowest)')
plt.ylabel('Freshman GPA')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### School Climate vs. School Problem Scale
#
# This scatter plot shows a negative relationship between the school problem scale and school climate. As the level of school problems increase(means less school problems, more positive overall), the school climate tends to decrease. The regression line confirms this downward trend, suggesting that more problems in a school are associated with a better overall climate. The model results also support this relationship, showing a statistically significant negative effect.
#
# This is a completely unexpected correlation as we expected a positive relationship, fewer school problems means better school climate. This negative relationship suggests possible coding-direction mismatch, however when double checking with the HSLS student codebook, it seems to be accurate. This could also suggest that there could be confound variables where we don't have the full picture of this relationship

# %%
plt.figure(figsize=(6, 5))
sns.lmplot(
    data=comb_df,
    x='SCHOOL_PROBLEM_SCALE',
    y='SCHOOL_CLIMATE_SCALE',
    x_jitter=0.05,
    y_jitter=0.05,
    fit_reg=True,
    scatter_kws={"s": 8},
    line_kws={'color': 'red'}
)
plt.title('School Climate vs. School Problem Scale')
plt.xlabel('School Problem Scale (higher = less problems)')
plt.ylabel('School Climate Scale')
plt.tight_layout()
plt.show()

X = sm.add_constant(comb_df['SCHOOL_PROBLEM_SCALE'])
y = comb_df['SCHOOL_CLIMATE_SCALE']
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     SCHOOL_CLIMATE_SCALE   R-squared:                       0.351
# Model:                              OLS   Adj. R-squared:                  0.350
# Method:                   Least Squares   F-statistic:                     1104.
# Date:                  Wed, 18 Mar 2026   Prob (F-statistic):          5.04e-194
# Time:                          20:01:38   Log-Likelihood:                -2547.4
# No. Observations:                  2048   AIC:                             5099.
# Df Residuals:                      2046   BIC:                             5110.
# Df Model:                             1
# Covariance Type:              nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0579      0.024     -2.428      0.015      -0.105      -0.011
# ...

# %% [markdown]
# #### GPA vs. School Problem Scale and School Climate Scale
#
# These plots compare the relationship between freshman GPA and two school-level factors: problem scale and climate scale. The left plot shows a slight negative relationship, where higher levels of school problems are associated with lower GPAs. In contrast, the right plot shows a slight positive relationship, suggesting that better school climate is associated with higher GPAs. However, both relationships are relatively weak, as the data points are widely spread.

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4), sharey=True)

sns.regplot(
    data=comb_df,
    x='SCHOOL_PROBLEM_SCALE',
    y='FRESHMAN_GPA',
    lowess=True,
    scatter_kws={'alpha': 0.2},
    ax=axes[0],
    line_kws={'color': 'red'}
)
axes[0].set_title('GPA vs. School Problem Scale')
axes[0].set_xlabel('School Problem Scale')
axes[0].set_ylabel('Freshman GPA')

sns.regplot(
    data=comb_df,
    x='SCHOOL_CLIMATE_SCALE',
    y='FRESHMAN_GPA',
    lowess=True,
    scatter_kws={'alpha': 0.2},
    ax=axes[1],
    line_kws={'color': 'red'}
)
axes[1].set_title('GPA vs. School Climate Scale')
axes[1].set_xlabel('School Climate Scale')
axes[1].set_ylabel('')

plt.tight_layout()
plt.show()

# %%
X = sm.add_constant(comb_df['SCHOOL_PROBLEM_SCALE'])
y = comb_df['FRESHMAN_GPA']
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           FRESHMAN_GPA   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     43.49
# Date:                Wed, 18 Mar 2026   Prob (F-statistic):           5.40e-11
# Time:                        20:01:38   Log-Likelihood:                -2706.0
# No. Observations:                2048   AIC:                             5416.
# Df Residuals:                    2046   BIC:                             5427.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    2.8132      0.026    109.250      0.000       2.763       2.864
# ...

# %%
X = sm.add_constant(comb_df['SCHOOL_CLIMATE_SCALE'])
y = comb_df['FRESHMAN_GPA']
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           FRESHMAN_GPA   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     19.64
# Date:                Wed, 18 Mar 2026   Prob (F-statistic):           9.86e-06
# Time:                        20:01:38   Log-Likelihood:                -2717.8
# No. Observations:                2048   AIC:                             5440.
# Df Residuals:                    2046   BIC:                             5451.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    2.8821      0.022    131.692      0.000       2.839       2.925
# ...

# %% [markdown]
# ### Distribution of Student School Motivation
# This plot shows the distribution of school motivation reported by students, which showed a heavy left skewed distribution. This indicates that more students gathered within this dataset are more academically motivated.

# %%
plt.figure(figsize=(6, 4))
sns.histplot(
    comb_df['STUDENT_SCHOOL_MOTIVATION'],
    binwidth=0.2,
    kde=True
)
plt.title('Distribution of Student School Motivation')
plt.xlabel('Motivation Scale')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Freshman GPA by Motivation Quintile
# This boxplot represents the student's Freshman GPA range relative to their motivation quintile. It is noted that their educational experiences are based off of high school, but their academic traits likely remain when moving onto their first-year of college. Shown in the boxplot, it is expected that the overall GPA will increase as student motivation increases, meaning they are likely more passionate and ambitious about performing well academically overall.

# %%
mot = comb_df[['STUDENT_SCHOOL_MOTIVATION', 'FRESHMAN_GPA']].dropna().copy()
mot['MOTIVATION_QUINTILE'] = pd.qcut(mot['STUDENT_SCHOOL_MOTIVATION'], 5,
                                     labels=['Q1', 'Q2', 'Q3', 'Q4', 'Q5'])

plt.figure(figsize=(6, 4))
sns.boxplot(
    data=mot,
    x='MOTIVATION_QUINTILE',
    y='FRESHMAN_GPA'
)
plt.title('Freshman GPA by Motivation Quintile')
plt.xlabel('Motivation Quintile (Q1 = lowest)')
plt.ylabel('Freshman GPA')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Mean Freshman GPA by Family Income Bracket
# This bar chart shows the mean Freshman GPA relative to the student's family's income bracket. While the correlation remains positive from the family income bracket of 1 to 7, the mean after that shows no clear trend, though the highest income bracket resulted in the highest mean freshman GPA. We inferred that as the income bracket increases, students perform higher academically due to a variety of resources such as tutoring, private schooling, and overall further academic support. However, the family income bracket of 10 and 12 seem relatively low considering the GPA of students in lower and higher income brackets. It is also worth noting that the income bracket of 10 and 12 contains the lowest sample >30 and <50 compared to other income brackets.

# %%
inc = comb_df[['FAMILY_INCOME_BRACKET', 'FRESHMAN_GPA']].dropna().copy()
print(inc.groupby('FAMILY_INCOME_BRACKET').size())

income_order = sorted(inc['FAMILY_INCOME_BRACKET'].unique())
plt.figure(figsize=(8, 4))
sns.barplot(
    data=inc,
    x='FAMILY_INCOME_BRACKET',
    y='FRESHMAN_GPA',
    order=income_order,
    estimator=np.mean,
    ci=95
)
plt.title('Mean Freshman GPA by Family Income Bracket')
plt.xlabel('Family Income Bracket')
plt.ylabel('Mean Freshman GPA')
plt.tight_layout()
plt.show()
# Out:
# FAMILY_INCOME_BRACKET
# 1      83
# 2     188
# 3     248
# 4     275
# 5     273
# 6     243
# 7     181
# 8     151
# 9      71
# 10     42
# 11     68
# 12     35
# 13    190
# dtype: int64
# /var/folders/xg/pjqjkzbx1lz9fgmz_njxvl6w0000gn/T/ipykernel_55697/163783489.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ### Freshman GPA vs Socialeconomic Composite score
# This scatterplot shows the Freshman GPA relative to the socioeconomic status. While the correlation is fairly low, it does show a positive trend where GPA tends to be higher as the socialeconomic score increases. This indicates that students with families with higher social/income status often perform better due to accessibility of resources compared to those with lower socioecomic status (around -1 to -2).

# %%
plt.figure(figsize=(6, 4))
sns.regplot(
    data=comb_df,
    x='SES_COMPOSITE_URBANICITY_ADJ',
    y='FRESHMAN_GPA',
    lowess=True,
    scatter_kws={'alpha': 0.2},
    line_kws={'color': 'red'}
)

plt.title('Freshman GPA vs SES Composite (Urbanicity Adjusted)')
plt.xlabel('SES Composite (Urbanicity Adjusted)')
plt.ylabel('Freshman GPA')
plt.tight_layout()
plt.show()

X = sm.add_constant(comb_df['SES_COMPOSITE_URBANICITY_ADJ'])
y = comb_df['FRESHMAN_GPA']
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           FRESHMAN_GPA   R-squared:                       0.052
# Model:                            OLS   Adj. R-squared:                  0.051
# Method:                 Least Squares   F-statistic:                     111.8
# Date:                Wed, 18 Mar 2026   Prob (F-statistic):           1.78e-25
# Time:                        20:01:39   Log-Likelihood:                -2673.1
# No. Observations:                2048   AIC:                             5350.
# Df Residuals:                    2046   BIC:                             5361.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                            2.7910      0.023    120.384      0.000       2.746       2.836
# ...

# %% [markdown]
# ### Household Size Distribution
# This histogram shows the household size distribution, which shows a normal distribution. This indicates that most children live in a household of 4-5 family members.

# %%
plt.figure(figsize=(6, 4))
sns.histplot(
    data=comb_df['HOUSEHOLD_SIZE'],
    binwidth=1,
)
plt.title('Household Size Distribution')
plt.xlabel('Household Size')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Mean Freshman GPA by Household size
# This plot shows the mean Freshman GPA relative to household size. A typical household size would be around 4, which contains the highest GPA mean. However, there is no clear correlation between freshman GPA and household size. A household of 2 would indicate that a student only has a single parent, which can drastically change life circumstances. On the contrary, a household of 5-6 or above would indicate less individualized attention between each child, which may result in a lower GPA as academic support is limited. However, the slight increase from 7+ household members is quite odd, considering the circumstances we highlighted above.

# %%
print(comb_df.groupby('HOUSEHOLD_SIZE').size())
household = comb_df[['HOUSEHOLD_SIZE', 'FRESHMAN_GPA']].clip(upper=7)
plt.figure(figsize=(6, 4))
sns.pointplot(
    data=household,
    x='HOUSEHOLD_SIZE',
    y='FRESHMAN_GPA',
    estimator=np.mean,
)
plt.title('Mean Freshman GPA by Household Size')
plt.xlabel('Household Size (7 = 7 or more)')
plt.ylabel('Mean Freshman GPA')
plt.tight_layout()
plt.show()
# Out:
# HOUSEHOLD_SIZE
# 2      80
# 3     355
# 4     825
# 5     505
# 6     178
# 7      73
# 8      18
# 9       9
# 10      3
# 11      2
# dtype: int64

# %% [markdown]
# ### Mean Freshman GPA by Number of High Schools Attended:
# This bar chart shows the mean Freshman GPA by the number of high schools attended in student's post-secondary education. We expected that there would be a negative correlation between the number of high schools attended and post-secondary freshman GPA; however, the data explains the opposite, where the highest GPA came students who attended 3 high schools. After analyzing the dataset, there was only one student in the dataset who attended 3 high schools. So after disregarding the singular student, we see a negative correlation.

# %%
hs = comb_df[['NUM_HS_ATTENDED', 'FRESHMAN_GPA']].dropna().copy()
hs = hs[hs['NUM_HS_ATTENDED'] < 3]
print(hs.groupby('NUM_HS_ATTENDED').size())

plt.figure(figsize=(6, 4))
sns.barplot(
    data=hs,
    x='NUM_HS_ATTENDED',
    y='FRESHMAN_GPA',
    estimator=np.mean,
)
plt.title('Mean Freshman GPA by Number of High Schools Attended')
plt.xlabel('Number of High Schools Attended')
plt.ylabel('Mean Freshman GPA')
plt.tight_layout()
plt.show()
# Out:
# NUM_HS_ATTENDED
# 1    2008
# 2      39
# dtype: int64

# %% [markdown]
# ### Making a heatmap to see what variables correlate with Freshman Gpa(the variable that we are choosing to demonstrate first year success)
# - First we have to drop some variables that we don't think are useful or represented already by other variables.
# - Second we drop other college outcome variables, we are only targetting predictor variables

# %%
corr_df = comb_df.copy()

drop_list = ['FRESHMAN_CREDITS_EARNED', 'FRESHMAN_CREDITS_ATTEMPTED',
            'HS_GPA_11TH','HS_GPA_10TH','HS_GPA_9TH', 'HS_GPA_12TH',
            'SAT_WRIT_AVG', 'ENROLLMENT_ATTAINMENT_STATUS' ]
corr_df = corr_df.drop(columns=drop_list)
print(corr_df.columns)
len(corr_df.columns)
# Out:
# Index(['FAMILY_INCOME_BRACKET', 'HOUSEHOLD_SIZE',
#        'SES_COMPOSITE_URBANICITY_ADJ', 'NUM_HS_ATTENDED',
#        'SCHOOL_PROBLEM_SCALE', 'SCHOOL_CLIMATE_SCALE',
#        'STUDENT_SCHOOL_MOTIVATION', 'TOTAL_AP_CREDITS', 'RIGOR', 'HS_GPA_ACAD',
#        'HS_GPA_WGT', 'ACT_SCHOOL_AVG', 'FRESHMAN_GPA', 'SAT_SCHOOL_AVG',
#        'HOURS_HOMEWORK', 'HS_GPA_CUM'],
#       dtype='object')
# 16

# %% [markdown]
# ### Correlation map analysis
# #### Variables with high correlation, meaning good chance of confounds
# - SES and Family bracket have high correlation, which makes sense. For our model we will only use SES as it provides more context to the surrounding
# - School problem scale and ACT and SAT school average show a high negative correlation, demonstrating that worse school shows some correlation to lower test scores. Whether that is due to a poorer envionrment, less funding, etc
# - Problem and climate scale also high have negative correlation
# - Each form of gpa have high correlation with each other but that is expected
#
# #### Factors that correlated freshmen gpa highly
# - All the highschool gpas showed the highest correlation with above .5
# - Total amount of Ap credits showed decent correlation also with .3
# - SES showed a higher correlation compared to family income bracket as expected so we are going to use that instead
# - Student school motivation, sat, act showed a low amount of correlation(.15) but still does make an impact
#
# #### Factors that had no impact or high noise
# - Household size, number of HS attended, hours of homework

# %%
plt.figure(figsize=(14, 10))
sns.heatmap(corr_df.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
df_hs_cum = comb_df[['HS_GPA_9TH', 'HS_GPA_10TH', 'HS_GPA_11TH', 'HS_GPA_12TH']]
comb_df['HS_GPA_CUM'] = df_hs_cum.mean(axis=1)

# Select key variables (adjust names if needed)
cols = [
    'HS_GPA_CUM',
    'TOTAL_AP_CREDITS',               
    'SES_COMPOSITE_URBANICITY_ADJ',
    'FRESHMAN_GPA'
]

df = comb_df[cols]


# Compute correlations with freshman GPA
corr = df.corr()['FRESHMAN_GPA'].drop('FRESHMAN_GPA')

# Sort values
corr = corr.sort_values(ascending=False)

# Plot
plt.figure()
bars = plt.bar(corr.index, corr.values)

# De-emphasize HS GPA (since already discussed)
for i, name in enumerate(corr.index):
    if 'HS_GPA' in name:
        bars[i].set_alpha(0.4)

plt.title("Key Predictors of College Freshman GPA")
plt.ylabel("Correlation with Freshman GPA")
plt.xticks(rotation=25)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/xg/pjqjkzbx1lz9fgmz_njxvl6w0000gn/T/ipykernel_55697/1934790111.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comb_df['HS_GPA_CUM'] = df_hs_cum.mean(axis=1)

# %% [markdown]
# ## Linear Model with the 5 highest correlation variables from heatmap
# - r^2 of .294, these 5 variables explain roughly 29.4% of the variance
# - Low f statistic means its statistically significant, and each variable is statistically significant
# - Each variable showed some contribution in increasing freshman gpa, with HS_GPA_CUM the highest
#
# r^2 of .294 shows that there is plenty left unexplained

# %%
corr_df.columns
# Out:
# Index(['FAMILY_INCOME_BRACKET', 'HOUSEHOLD_SIZE',
#        'SES_COMPOSITE_URBANICITY_ADJ', 'NUM_HS_ATTENDED',
#        'SCHOOL_PROBLEM_SCALE', 'SCHOOL_CLIMATE_SCALE',
#        'STUDENT_SCHOOL_MOTIVATION', 'TOTAL_AP_CREDITS', 'RIGOR', 'HS_GPA_ACAD',
#        'HS_GPA_WGT', 'ACT_SCHOOL_AVG', 'FRESHMAN_GPA', 'SAT_SCHOOL_AVG',
#        'HOURS_HOMEWORK', 'HS_GPA_CUM'],
#       dtype='object')

# %%
best_5_lm = smf.ols(formula = "FRESHMAN_GPA~HS_GPA_CUM + TOTAL_AP_CREDITS + SES_COMPOSITE_URBANICITY_ADJ + STUDENT_SCHOOL_MOTIVATION + ACT_SCHOOL_AVG", data = comb_df).fit()
best_5_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           FRESHMAN_GPA   R-squared:                       0.294
# Model:                            OLS   Adj. R-squared:                  0.292
# Method:                 Least Squares   F-statistic:                     170.1
# Date:                Wed, 18 Mar 2026   Prob (F-statistic):          1.57e-151
# Time:                        20:18:07   Log-Likelihood:                -2371.0
# No. Observations:                2048   AIC:                             4754.
# Df Residuals:                    2042   BIC:                             4788.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Linear Model with only Academic Indicators
# - R² = 0.285, so these academic features explain about 28.5% of the variance in freshman GPA.
# - The model is statistically significant overall (F-test p << 0.001).
# - HS_GPA_CUM is the strongest predictor, with TOTAL_AP_CREDITS also showing a meaningful positive contribution.
# - RIGOR and HOURS_HOMEWORK are not statistically significant in this model, suggesting limited added value once GPA and AP credits are included.
# - Compared to the 5-variable model (R² = 0.294), this is very close, indicating most predictive signal is concentrated in cumulative high school GPA and AP/IB preparation.
#
# As with prior models, a substantial share of freshman GPA variance remains unexplained.

# %%
academic_lm = smf.ols(formula='FRESHMAN_GPA~HS_GPA_CUM + TOTAL_AP_CREDITS + RIGOR + HOURS_HOMEWORK', data = comb_df).fit()
academic_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           FRESHMAN_GPA   R-squared:                       0.285
# Model:                            OLS   Adj. R-squared:                  0.283
# Method:                 Least Squares   F-statistic:                     203.4
# Date:                Wed, 18 Mar 2026   Prob (F-statistic):          5.59e-147
# Time:                        20:29:20   Log-Likelihood:                -2384.3
# No. Observations:                2048   AIC:                             4779.
# Df Residuals:                    2043   BIC:                             4807.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Linear Model with only Environment Indicators(Family + School)
# - R² = 0.063, so environment-context variables explain about 6.3% of freshman GPA variance, much lower than the academic-only model.
# - The model is statistically significant overall (F-test p << 0.001), but most individual predictors are weak.
# ### Predictors
# Significant predictors here are: SES_COMPOSITE_URBANICITY_ADJ (positive), NUM_HS_ATTENDED (negative)
#
# Non-significant predictors in this specification include: HOUSEHOLD_SIZE, SCHOOL_PROBLEM_SCALE, SCHOOL_CLIMATE_SCALE, ACT_SCHOOL_AVG, and SAT_SCHOOL_AVG.
#
# ### Findings
# - Compared to academic-only (R² = 0.285) and combined (R² ≈ 0.294), this suggests environment variables alone have weaker predictive power for first-year GPA.
# - The large condition number indicates possible scaling/multicollinearity issues, so coefficients should be interpreted cautiously.

# %%
environment_terms = "HOUSEHOLD_SIZE + SES_COMPOSITE_URBANICITY_ADJ + NUM_HS_ATTENDED + SCHOOL_PROBLEM_SCALE + SCHOOL_CLIMATE_SCALE + ACT_SCHOOL_AVG + SAT_SCHOOL_AVG"
env_lm = smf.ols(formula = 'FRESHMAN_GPA~'+environment_terms, data = comb_df).fit()
env_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           FRESHMAN_GPA   R-squared:                       0.063
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     19.55
# Date:                Wed, 18 Mar 2026   Prob (F-statistic):           1.78e-25
# Time:                        20:31:34   Log-Likelihood:                -2661.1
# No. Observations:                2048   AIC:                             5338.
# Df Residuals:                    2040   BIC:                             5383.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Combined Model
# ### Interesting findings when including all Factors
# - The model explains about 29.8% of variation in freshman GPA (R² = 0.298), only a small gain over the academic-only model.
# - Rigor and hours homework become extremely useless, high p values of above .7.
# - ACT School Average becomes statistically insignificant also with p value of .4, but sat seems to stay way lower at 0.074. Potentially showing SAT has more predictive power
# - Only statistically significant values are HS GPA,AP CREDITS,SES Score, and SCHOOL_PROBLEM_SCALE which is very interesting.
#
# #### Overall conclusion
# - most predictive power still comes from cumulative academic preparation, while context variables add smaller incremental value.
# - The high condition number suggests multicollinearity/scaling issues, so individual coefficients should be interpreted with caution.
# - High condition number suggesting high multicollinearity, results cant be taken too seriously

# %%
combined_terms_full = (
    "HS_GPA_CUM + TOTAL_AP_CREDITS + RIGOR + HOURS_HOMEWORK + "
    "HOUSEHOLD_SIZE + SES_COMPOSITE_URBANICITY_ADJ + "
    "NUM_HS_ATTENDED + SCHOOL_PROBLEM_SCALE + SCHOOL_CLIMATE_SCALE + "
    "ACT_SCHOOL_AVG + SAT_SCHOOL_AVG"
)
comb_lm = smf.ols(formula = 'FRESHMAN_GPA~'+combined_terms_full, data = comb_df).fit()
comb_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           FRESHMAN_GPA   R-squared:                       0.298
# Model:                            OLS   Adj. R-squared:                  0.294
# Method:                 Least Squares   F-statistic:                     78.56
# Date:                Wed, 18 Mar 2026   Prob (F-statistic):          1.11e-147
# Time:                        20:38:08   Log-Likelihood:                -2365.3
# No. Observations:                2048   AIC:                             4755.
# Df Residuals:                    2036   BIC:                             4822.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Testing a Non Linear Prediction Model
# - See if it can add any insights that linear models cannot
# - We will be using XGBoost as it is good for tabular data
# - From our linear models, we learn to remove Homework hours and rigor, we will keep the rest to test on

# %% [markdown]
# ## Ethics
#
# Instructions: Keep the contents of this cell. For each item on the checklist
# -  put an X there if you've considered the item
# -  IF THE ITEM IS RELEVANT place a short paragraph after the checklist item discussing the issue.
#
# Items on this checklist are meant to provoke discussion among good-faith actors who take their ethical responsibilities seriously. Your teams will document these discussions and decisions for posterity using this section.  You don't have to solve these problems, you just have to acknowledge any potential harm no matter how unlikely.
#
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
# > All students are aware that their data would be used. No data was collected through force or secrecy.
#  - [ ] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
# > No names, contact information, or other identifiers were collected or stored. Students will be differentiated using a unique number identifier, eliminating the possibility of PII.
#  - [ ] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
# > All data is from public sources and contains no PII; access is limited to project members.
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  > No, individuals will not be able to request for the removal of their data.
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#  > Temporary copies of the dataset will be deleted from local machines once grading is complete. This minimizes long-term risk of unintended reuse. No archival use of the data is planned. Retention is strictly tied to the academic lifecycle of the project.
#
# ### C. Analysis
#  - [ ] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#  > We have no relevant stakeholders.
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#  > These biases could influence correlations observed in the analysis. So, findings will be framed as descriptive rather than prescriptive. The analysis avoids claims about inherent ability or merit. Observed patterns are interpreted as outcomes shaped by broader educational contexts.
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
# > Axes, scales, and labels are chosen carefully to avoid misleading interpretations. Any uncertainty or variability in the data will be clearly shown when relevant. Visualizations will not be optimized to support a predetermined narrative. Alternative explanations for trends will be acknowledged.
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#  > No personally identifiable information will be used or displayed during analysis.
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#  > Code and analysis steps are version-controlled and clearly commented. This allows future reviewers to trace decisions and identify potential issues. Assumptions made during preprocessing aredocumented.
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#  > Features correlated with socioeconomic status or institutional advantage are not considered in the analysis, making it impossible for the model to rely on discriminatory variables.
#  - [ ] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#  > We have not yet tested any model results.
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#  > Tradeoffs between accuracy, interpretability, and robustness are considered. Metrics are chosen to reflect the exploratory goals of the project. No single metric is treated as definitive. Performance results are interpreted within context rather than as absolute measures.
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#  > Complex models are avoided where simpler explanations suffice. When predictions are discussed, their uncertainty is emphasized as to reduce the risk of inappropriate reliance on the model.
#  - [] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# ### E. Deployment
#  - [ ] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  > We will not be deploying the model. For this reason, this ethical consideration is irrelevant.
#  - [ ] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  > Since the model will not be deployed, this ethical issue does not apply.
#  - [ ] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  > As the model will not be used in practice, this ethical consideration can be disregarded.
#  - [ ] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#  > The model will not be implemented, so this ethical point is not pertinent.

# %% [markdown]
# ## Discusison and Conclusion
#
# Wrap it all up here.  Somewhere between 3 and 10 paragraphs roughly.
# 1. Summarize the important results you made
# 2. This is a good time to refer back to your Background section and review how this work extended the previous stuff.
# 3. Try to bring all the different results together into a bigger picture... what have we learned?
# 4. Often what we learned is confusing.  Discuss if there are contradictory results how that might have happened
# 5. Discuss the limitations of your work. e.g, is the dataset a biased sample? would more data make you more confident? would longitudinal instead of cross-sectional data helpful? is there evidence that the phenomena you're investigating may change over time? etc
# 6. If you would like, you can also say what the next steps in this investigation might be if the work was to continue outside this class
#
# From this project
